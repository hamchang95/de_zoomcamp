# %%
import urllib
import os

# %%
l_taxi_type = ['yellow', 'green']
l_year = [2019, 2020]
l_month = [f'{i:02d}' for i in range(1, 13)]

# %% [markdown]
# https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2019-01.csv.gz

# %%
os.getcwd()
# Out:
# 'c:\\Users\\hanna\\Documents\\de_zoomcamp\\wk4_lesson'

# %%
def get_file(taxi_type, year, month):
    base_path = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download'
    full_path = f'{base_path}/{taxi_type}/{taxi_type}_tripdata_{year}-{month}.csv.gz'
    file_path = os.path.join('.', f"{taxi_type}_tripdata_{year}-{month}.csv.gz")
    
    try:
        print(f"Downloading {full_path}...")
        urllib.request.urlretrieve(full_path, file_path)
        print(f"Downloaded: {file_path}")
        return file_path
    except Exception as e:
        print(f"Failed to download {file_path}: {e}")
        return None

# %%
if __name__ == "__main__":
    for taxi_type in l_taxi_type:
        for year in l_year:
            for month in l_month:
                get_file(taxi_type, year, month)
# Out:
# ...
# Downloaded: .\green_tripdata_2019-01.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-02.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-03.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-04.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-05.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-06.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-07.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-08.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-09.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-10.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-11.csv.gz
# ...
# Downloaded: .\green_tripdata_2019-12.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-01.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-02.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-03.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-04.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-05.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-06.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-07.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-08.csv.gz
# ...
# Downloaded: .\green_tripdata_2020-09.csv.gz
# ...
